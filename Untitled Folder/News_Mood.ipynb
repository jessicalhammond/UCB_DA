# %%
from datetime import datetime
import tweepy
import json
import numpy as np
import matplotlib.pyplot as plt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from config import consumer_key, consumer_secret, access_token, access_token_secret

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
# news_outlets list
# news_outlets = ["BBC", 'CBS', 'CNN', 'Fox', 'New York Times']
news_outlets = "@BBC"
#records to review
n_tweets = 100
sentiment_data = {
    "compound_score" : [],
    "positive_score" : []
}

#lists created in loop for sentiment and target.
for outlet in news_outlets:
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []
    name = []

    for item in tweepy.Cursor(api.user_timeline, id=outlet, tweet_mode="extended").items(n_tweets):
        tweet = status._json
        result = analyzer.polarity_scores(tweet['full_text'])
        name.append(tweet['user']['name'])
        compound_list.append(result['compound'])
        positive_list.append(result['pos'])
        negative_list.append(result['neg'])
        neutral_list.append(result['neu'])
        print(tweet)
    
#     sentiment_data["name"].append(name
#     sentiment_data["compound_score"].append(compound_list)
# Out:
# {'created_at': 'Thu Apr 05 13:58:29 +0000 2012', 'id': 187902028217987072, 'id_str': '187902028217987072', 'full_text': "Hey World, It's B!\nI'm so excited to invite you to my new http://t.co/fZxlrtAh - we've been working\nhard, and it's finally ready for you XO", 'truncated': False, 'display_text_range': [0, 139], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'http://t.co/fZxlrtAh', 'expanded_url': 'http://beyonce.com', 'display_url': 'beyonce.com', 'indices': [58, 78]}]}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 31239408, 'id_str': '31239408', 'name': 'BEYONCÉ', 'screen_name': 'Beyonce', 'location': '', 'description': '', 'url': 'http://t.co/e8ORwX0pFo', 'entities': {'url': {'urls': [{'url': 'http://t.co/e8ORwX0pFo', 'expanded_url': 'h
# ...

# %%
num_lists = int(raw_input("How many lists do you want? "))
   lists = []
   for p in range(num_lists):
        lists.append([])compound_list = []
        
        # iterate through a list and create lists within a list.

# %%
# # Target User Account
# target_user = "@Beyonce"

# # Variables for holding sentiments
# compound_list = []
# positive_list = []
# negative_list = []
# neutral_list = []

# # Number of tweets to retrieve
# n_tweets = 200

# for status in tweepy.Cursor(api.user_timeline, id=target_user, tweet_mode="extended").items(n_tweets):
#     tweet = status._json
#     target = (tweet['full_text'])
#     result = analyzer.polarity_scores(target)
#     compound_list.append(result['compound'])
#     positive_list.append(result['pos'])
#     negative_list.append(result['neg'])
#     neutral_list.append(result['neu'])
